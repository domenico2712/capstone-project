# %%
import requests
import pandas as pd

# %%
link_file = "https://esploradati.istat.it/SDMXWS/rest/data/41_983"
headers = {'Accept': 'application/vnd.sdmx.data+csv;version=1.0.0'}
print("Downloading data...")
# Out:
# Downloading data...

# %%
r = requests.get(link_file, headers=headers)
print(r.status_code)

# %%
with open("../data_raw/data.csv", "wb") as f:
    f.write(r.content)

print("Data downloaded and saved to ../data_raw/data.csv")
# Out:
# Data downloaded and saved to ../data_raw/data.csv

# %%
df_istat = pd.read_csv("../data_raw/data.csv")
df_istat.head()
# Out:
# Empty DataFrame
# Columns: [Error during writing responce]
# Index: []

# %%
df_istat.shape
# Out:
# (0, 1)

# %%
df_istat.columns
# Out:
# Index(['Error during writing responce'], dtype='str')

# %%
df_istat.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 1 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Error during writing responce  0 non-null      object
# dtypes: object(1)
# memory usage: 132.0+ bytes

# %%
df_istat.describe()
# Out:
#        Error during writing responce
# count                              0
# unique                             0
# top                              NaN
# freq                             NaN

# %% [markdown]
# CONCLUSION

# %% [markdown]
# The data has been successfully fetched from the ISTAT API and saved to a CSV file.
# Further data cleaning and analysis will be performed in the next steps.
